# %%
# Mar 10 2018

#data analysis libraries 
import numpy as np
import pandas as pd

#visualization libraries
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

#ignore warnings
import warnings
warnings.filterwarnings('ignore')

# %%
#import train and test CSV files
train = pd.read_csv("data/USvideos.csv")

#take a look at the training data
train.describe(include="all")
# Out:
#            video_id trending_date                              title  \
# count         21965         21965                              21965
# unique         4547           110                               4606
# top     sXP6vliZIHI      18.24.02  Selena Gomez, Marshmello - Wolves
# freq             14           200                                 18
# mean            NaN           NaN                                NaN
# std             NaN           NaN                                NaN
# min             NaN           NaN                                NaN
# 25%             NaN           NaN                                NaN
# 50%             NaN           NaN                                NaN
# 75%             NaN           NaN                                NaN
# max             NaN           NaN                                NaN
#
#        channel_title   category_id              publish_time    tags  \
# count          21965  21965.000000                     21965   21965
# unique          1912           NaN                      4483    4319
# top             ESPN           NaN  2018-02-16T14:00:03.000Z  [none]
# freq             107           NaN                        21     978
# mean             NaN     20.026861                       NaN     NaN
# std              NaN      7.605711                       NaN     NaN
# min              NaN      1.000000                       NaN     NaN
# 25%              NaN     17.000000                       NaN     NaN
# 50%              NaN     24.000000                       NaN     NaN
# 75%              NaN     25.000000                       NaN     NaN
# max              NaN     43.000000                       NaN     NaN
#
#                views         likes      dislikes  comment_count  \
# count   2.196500e+04  2.196500e+04  2.196500e+04   2.196500e+04
# unique           NaN           NaN           NaN            NaN
# top              NaN           NaN           NaN            NaN
# freq             NaN           NaN           NaN            NaN
# mean    1.280524e+06  4.457964e+04  2.874186e+03   5.767170e+03
# std     4.213686e+06  1.466600e+05  3.669720e+04   3.338983e+04
# min     5.490000e+02  0.000000e+00  0.000000e+00   0.000000e+00
# 25%     1.070160e+05  2.138000e+03  9.800000e+01   3.090000e+02
# 50%     3.387900e+05  9.350000e+03  3.440000e+02   1.068000e+03
# 75%     1.039254e+06  3.033900e+04  1.161000e+03   3.471000e+03
# max     1.493761e+08  3.093544e+06  1.674420e+06   1.361580e+06
#
#                                         thumbnail_link comments_disabled  \
# count                                            21965             21965
# unique                                            4547                 2
# top     https://i.ytimg.com/vi/sXP6vliZIHI/default.jpg             False
# freq                                                14             21587
# mean                                               NaN               NaN
# std                                                NaN               NaN
# min                                                NaN               NaN
# 25%                                                NaN               NaN
# 50%                                                NaN               NaN
# 75%                                                NaN               NaN
# max                                                NaN               NaN
#
#        ratings_disabled video_error_or_removed  \
# count             21965                  21965
# unique                2                      2
# top               False                  False
# freq              21832                  21961
# mean                NaN                    NaN
# std                 NaN                    NaN
# min                 NaN                    NaN
# 25%                 NaN                    NaN
# 50%                 NaN                    NaN
# 75%                 NaN                    NaN
# max                 NaN                    NaN
#
#                                               description
# count                                               21546
# unique                                               4741
# top     Jukin Media Verified (Original) * For licensin...
# freq                                                   46
# mean                                                  NaN
# std                                                   NaN
# min                                                   NaN
# 25%                                                   NaN
# 50%                                                   NaN
# 75%                                                   NaN
# max                                                   NaN

# %%
train.sample(5)
# Out:
#           video_id trending_date  \
# 1072   szs2GAYwMHo      17.19.11
# 3637   9fe3ECuYWlI      17.02.12
# 15663  mUSv8b-V5I4      18.02.02
# 1878   7Bgj9c48zHU      17.23.11
# 17937  A3_c-aSZF5M      18.13.02
#
#                                                    title     channel_title  \
# 1072   KUWTK | A Very Kardashian Holiday Sneak Peek | E!  E! Entertainment
# 3637           Americans Try To Explain The Royal Family     BuzzFeedVideo
# 15663  Here’s Why the 2018 Lincoln Navigator is Worth...       Doug DeMuro
# 1878         How to do a beauty Vlog for Tarte Cosmetics          Sailor J
# 17937  JOSIE Official Trailer (2018) Sophie Turner, D...     Rapid Trailer
#
#        category_id              publish_time  \
# 1072            24  2017-11-16T15:10:46.000Z
# 3637            22  2017-12-01T01:00:58.000Z
# 15663            2  2018-01-30T16:58:07.000Z
# 1878            24  2017-11-21T17:44:17.000Z
# 17937            1  2018-02-06T18:37:12.000Z
#
#                                                     tags    views  likes  \
# 1072   Real Time|"Kardashian Holiday"|"Sneak Peek"|"K...   361618   3239
# 3637   buzzfeed|"buzzfeedvideo"|"buzzfeed video"|"meg...   225107   5466
# 15663  lincoln navigator|"navigator"|"lincoln navigat...  1057423  23740
# 1878   Tarte|"Makeup"|"Gift"|"Comedy"|"Eyeshadow"|"Fo...    60404   8400
# 17937  Josie|"Trailer"|"Josie Trailer"|"Josie Trailer...   155032    527
#
#        dislikes  comment_count  \
# 1072         77            133
# 3637        468            999
# 15663      1268           8755
# 1878         88           2888
# 17937        64            113
#
#                                        thumbnail_link  comments_disabled  \
# 1072   https://i.ytimg.com/vi/szs2GAYwMHo/default.jpg              False
# 3637   https://i.ytimg.com/vi/9fe3ECuYWlI/default.jpg              False
# 15663  https://i.ytimg.com/vi/mUSv8b-V5I4/default.jpg              False
# 1878   https://i.ytimg.com/vi/7Bgj9c48zHU/default.jpg              False
# 17937  https://i.ytimg.com/vi/A3_c-aSZF5M/default.jpg              False
#
#        ratings_disabled  video_error_or_removed  \
# 1072              False                   False
# 3637              False                   False
# 15663             False                   False
# 1878              False                   False
# 17937             False                   False
#
#                                              description
# 1072   Ring in the holidays with a special Keeping Up...
# 3637   They're sorta like the Kardashians of UK.\n\nC...
# 15663  GO READ MY COLUMN! http://autotradr.co/Overste...
# 1878   Song: Samurai Champloo Hip Hop Remix- SparX Be...
# 17937  JOSIE Official Trailer (2018) Sophie Turner, D...
